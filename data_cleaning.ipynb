# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Read the data into dataframes
df_joined = pd.read_csv('Resources/df_joined_data.csv')
df_joined.head()
# Out:
# /var/folders/d8/9qjs08z542bfkg2hvyk3gfq00000gn/T/ipykernel_45369/4288075586.py:2: DtypeWarning: Columns (79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_joined = pd.read_csv('Resources/df_joined_data.csv')
#    x             pin  Property Class  Neighborhood Code  Land Square Feet  \
# 0  0  20264140050000             211                 70            4687.0
# 1  1  20143100350000             207                 70            2790.0
# 2  2  25221150220000             202                210            4000.0
# 3  3  25033000760000             210                111            2700.0
# 4  4  26174070030000             203                240            4312.0
#
#    Town Code  Type of Residence  Apartments  Wall Material  Roof Material  \
# 0         70                2.0         0.0            2.0            1.0
# 1         70                2.0         0.0            1.0            1.0
# 2         70                1.0         0.0            1.0            1.0
# 3         70                2.0         0.0            2.0            1.0
# 4         70                5.0         0.0            2.0            1.0
#
#    ...  lake_michigan_data_year  nearest_major_road_dist_ft  \
# 0  ...                   2022.0                  764.136594
# 1  ...                   2022.0                 4188.862414
# 2  ...                      NaN                         NaN
# 3  ...                   2016.0                         NaN
# 4  ...                      NaN                         NaN
#
#    nearest_metra_stop_dist_ft  nearest_park_dist_ft  nearest_railroad_dist_ft  \
# 0                 1935.453861           2132.176749               1055.883106
# 1                 2896.061077            886.525144               1745.812282
# 2                         NaN                   NaN                       NaN
# 3                 5712.006728                   NaN                       NaN
# 4                         NaN                   NaN                       NaN
#
#    nearest_water_name  nearest_water_dist_ft  nearest_neighbor_1_dist_ft  \
# 0        South Lagoon            7762.535182                   35.427683
# 1                 NaN            2559.083259                   43.383443
# 2                 NaN                    NaN                         NaN
# 3                 NaN            9265.784793                   30.013366
# 4                 NaN                    NaN                   34.492083
#
#    nearest_neighbor_2_dist_ft  nearest_neighbor_3_dist_ft
# 0                   37.501601                   68.738677
# 1                   76.822828                   82.441660
# 2                         NaN                         NaN
# 3                   31.806947                   60.028247
# 4                   34.810349                   68.982910
#
# [5 rows x 124 columns]

# %%
df_joined = df_joined.drop(columns=['Design Plan', 'Cathedral Ceiling', 'chicago_community_area_num', 'chicago_community_area_name', 'qualified_opportunity_zone_num'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_joined = df_joined.drop(columns=['Design Plan', 'Cathedral Ceiling', 'chicago_community_area_num', 'chicago_community_area_name', 'qualified_opportunity_zone_num'])
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Design Plan', 'Cathedral Ceiling', 'chicago_community_area_num', 'chicago_community_area_name', 'qualified_opportunity_zone_num'] not found in axis"

# %%
#deleting Sale Date, bc Sale Year is available. Deleting Condition, Desirability and Utility, bc they are not needed for the analysis/minimal data available
df_joined = df_joined.drop(columns=['Deed No.', 'Modeling Group', 'Sale Date', 'Condition, Desirability and Utility', 'Condo Class Factor'])

# %%
df_joined = df_joined.drop(columns=['Condo Strata', 'Sale Quarter',	'Sale Half-Year', 'Sale Quarter of Year', 'Sale Month of Year',	'Sale Half of Year', 'Most Recent Sale', 'Age Squared',	'Age Decade', 'Age Decade Squared'])

# %%
df_joined = df_joined.drop(columns=['Pure Market Filter', 'Square root of lot size', 'Square root of age',	'Square root of improvement size'])

# %%
#Removed Renovation, bc only one row had data
df_joined = df_joined.drop(columns=['subdivision_id', 'num_pin_in_half_mile', 'lake_michigan_data_year', 'Wall Material', 'Roof Material', 'Renovation', 'Site Desirability'])

# %%
#Not much data in Total Building Square Feet 
df_joined = df_joined.drop(columns=['Number of Commercial Units', 'Total Building Square Feet', 'Attic Finish', 'Construction Quality'])

# %%
#redundant columns
df_joined = df_joined.drop(columns=['class', 'tax_district_code', 'tax_district_code', 'property_address', 'flood_fs_factor', 'flood_fs_risk_direction', 'ohare_noise_contour_no_buffer_bool', 'ohare_noise_contour_half_mile_buffer_bool',	'airport_noise_dnl', 'airport_noise_data_year', 'nearest_major_road_dist_ft', 'township_code', 'property_address'])

# %%
#pin,sale_price,sale_year,est_land,est_bldg,age,addr,latitude, longitude,hd_sf,n_units,bldg_sf,geometry,pri_neigh,sec_neigh,shape_area,shape_len,side,index_right,GEO_ID

# %%
df_joined.head()
# Out:
#    x             pin  Property Class  Neighborhood Code  Land Square Feet  \
# 0  0  20264140050000             211                 70            4687.0
# 1  1  20143100350000             207                 70            2790.0
# 2  2  25221150220000             202                210            4000.0
# 3  3  25033000760000             210                111            2700.0
# 4  4  26174070030000             203                240            4312.0
#
#    Town Code  Type of Residence  Apartments  Rooms  Bedrooms  ...  \
# 0         70                2.0         0.0   11.0       4.0  ...
# 1         70                2.0         0.0    7.0       3.0  ...
# 2         70                1.0         0.0    5.0       2.0  ...
# 3         70                2.0         0.0    5.0       3.0  ...
# 4         70                5.0         0.0    6.0       3.0  ...
#
#    nearest_cta_stop_dist_ft  lake_michigan_dist_ft  \
# 0               9794.218079            8395.770716
# 1               1944.855626            6360.931520
# 2                       NaN                    NaN
# 3               2156.808533           21800.837272
# 4                       NaN                    NaN
#
#    nearest_metra_stop_dist_ft  nearest_park_dist_ft  nearest_railroad_dist_ft  \
# 0                 1935.453861           2132.176749               1055.883106
# 1                 2896.061077            886.525144               1745.812282
# 2                         NaN                   NaN                       NaN
# 3                 5712.006728                   NaN                       NaN
# 4                         NaN                   NaN                       NaN
#
#    nearest_water_name  nearest_water_dist_ft  nearest_neighbor_1_dist_ft  \
# 0        South Lagoon            7762.535182                   35.427683
# 1                 NaN            2559.083259                   43.383443
# 2                 NaN                    NaN                         NaN
# 3                 NaN            9265.784793                   30.013366
# 4                 NaN                    NaN                   34.492083
#
#    nearest_neighbor_2_dist_ft  nearest_neighbor_3_dist_ft
# 0                   37.501601                   68.738677
# 1                   76.822828                   82.441660
# 2                         NaN                         NaN
# 3                   31.806947                   60.028247
# 4                   34.810349                   68.982910
#
# [5 rows x 78 columns]

# %%
df_joined = df_joined.drop(columns=['x'])

# %%
df_joined
# Out:
#                    pin  Property Class  Neighborhood Code  Land Square Feet  \
# 0       20264140050000             211                 70            4687.0
# 1       20143100350000             207                 70            2790.0
# 2       25221150220000             202                210            4000.0
# 3       25033000760000             210                111            2700.0
# 4       26174070030000             203                240            4312.0
# ...                ...             ...                ...               ...
# 212400  16121020080000             211                101            3175.0
# 212401  17172120161351             299                131           38130.0
# 212402  17082240081014             299                120            7136.0
# 212403  13251310220000             211                150            3018.0
# 212404  17193040270000             203                141            2976.0
#
#         Town Code  Type of Residence  Apartments  Rooms  Bedrooms  Basement  \
# 0              70                2.0         0.0   11.0       4.0       1.0
# 1              70                2.0         0.0    7.0       3.0       1.0
# 2              70                1.0         0.0    5.0       2.0       1.0
# 3              70                2.0         0.0    5.0       3.0       1.0
# 4              70                5.0         0.0    6.0       3.0       1.0
# ...           ...                ...         ...    ...       ...       ...
# 212400         77                2.0         2.0    7.0       4.0       1.0
# 212401         77                NaN         NaN    NaN       NaN       NaN
# 212402         77                NaN         NaN    NaN       NaN       NaN
# 212403         77                3.0         3.0   18.0       9.0       1.0
# 212404         77                1.0         0.0    4.0       2.0       2.0
#
#         ...  nearest_cta_stop_dist_ft  lake_michigan_dist_ft  \
# 0       ...               9794.218079            8395.770716
# 1       ...               1944.855626            6360.931520
# 2       ...                       NaN                    NaN
# 3       ...               2156.808533           21800.837272
# 4       ...                       NaN                    NaN
# ...     ...                       ...                    ...
# 212400  ...               3110.694686           22713.838616
# 212401  ...                       NaN                    NaN
# 212402  ...                       NaN                    NaN
# 212403  ...                       NaN                    NaN
# 212404  ...                       NaN                    NaN
#
#         nearest_metra_stop_dist_ft  nearest_park_dist_ft  \
# 0                      1935.453861           2132.176749
# 1                      2896.061077            886.525144
# 2                              NaN                   NaN
# 3                      5712.006728                   NaN
# 4                              NaN                   NaN
# ...                            ...                   ...
# 212400                 1663.550266                   NaN
# 212401                         NaN                   NaN
# 212402                         NaN                   NaN
# 212403                         NaN                   NaN
# 212404                         NaN                   NaN
#
#         nearest_railroad_dist_ft  nearest_water_name  nearest_water_dist_ft  \
# 0                    1055.883106        South Lagoon            7762.535182
# 1                    1745.812282                 NaN            2559.083259
# 2                            NaN                 NaN                    NaN
# 3                            NaN                 NaN            9265.784793
# 4                            NaN                 NaN                    NaN
# ...                          ...                 ...                    ...
# 212400                       NaN                 NaN            3842.508220
# 212401                       NaN                 NaN                    NaN
# 212402                       NaN                 NaN                    NaN
# 212403                       NaN                 NaN                    NaN
# 212404                       NaN                 NaN            5058.506892
#
#         nearest_neighbor_1_dist_ft  nearest_neighbor_2_dist_ft  \
# 0                        35.427683                   37.501601
# 1                        43.383443                   76.822828
# 2                              NaN                         NaN
# 3                        30.013366                   31.806947
# 4                        34.492083                   34.810349
# ...                            ...                         ...
# 212400                   25.004712                   37.491853
# 212401                  132.585415                  155.464516
# 212402                   70.440016                   78.833218
# 212403                   37.086735                   74.702324
# 212404                   24.003443                   24.004172
#
#         nearest_neighbor_3_dist_ft
# 0                        68.738677
# 1                        82.441660
# 2                              NaN
# 3                        60.028247
# 4                        68.982910
# ...                            ...
# 212400                   50.010324
# 212401                  160.264510
# 212402                  107.208034
# 212403                   82.574120
# 212404                   47.993710
#
# [212405 rows x 77 columns]

# %%
df_filtered = df_joined[(df_joined['Sale Year'] >= 2018) & (df_joined['Sale Year'] <= 2023)]
df_filtered
# Out:
#                    pin  Property Class  Neighborhood Code  Land Square Feet  \
# 7       20254260180000             203                 80            3750.0
# 8       20232190220000             211                 70            5000.0
# 12      25153030260000             202                210            4158.0
# 13      20232230451019             299                 70           25066.0
# 14      20271160150000             203                 30            5600.0
# ...                ...             ...                ...               ...
# 212391  17051240681004             299                120            5846.0
# 212394  16162141890000             295                 80            1017.0
# 212400  16121020080000             211                101            3175.0
# 212401  17172120161351             299                131           38130.0
# 212404  17193040270000             203                141            2976.0
#
#         Town Code  Type of Residence  Apartments  Rooms  Bedrooms  Basement  \
# 7              70                1.0         0.0    6.0       3.0       1.0
# 8              70                3.0         6.0   30.0      12.0       1.0
# 12             70                1.0         0.0    4.0       2.0       4.0
# 13             70                NaN         NaN    NaN       NaN       NaN
# 14             70                1.0         0.0    4.0       3.0       3.0
# ...           ...                ...         ...    ...       ...       ...
# 212391         77                NaN         NaN    NaN       NaN       NaN
# 212394         77                2.0         0.0    4.0       2.0       2.0
# 212400         77                2.0         2.0    7.0       4.0       1.0
# 212401         77                NaN         NaN    NaN       NaN       NaN
# 212404         77                1.0         0.0    4.0       2.0       2.0
#
#         ...  nearest_cta_stop_dist_ft  lake_michigan_dist_ft  \
# 7       ...                       NaN                    NaN
# 8       ...                       NaN                    NaN
# 12      ...               8641.316080           26084.996093
# 13      ...                       NaN                    NaN
# 14      ...                       NaN                    NaN
# ...     ...                       ...                    ...
# 212391  ...                988.630952           10464.074256
# 212394  ...               1952.905851           35789.669486
# 212400  ...               3110.694686           22713.838616
# 212401  ...                       NaN                    NaN
# 212404  ...                       NaN                    NaN
#
#         nearest_metra_stop_dist_ft  nearest_park_dist_ft  \
# 7                              NaN                   NaN
# 8                              NaN                   NaN
# 12                     2717.148357                   NaN
# 13                             NaN                   NaN
# 14                             NaN                   NaN
# ...                            ...                   ...
# 212391                 4886.881878                   NaN
# 212394                11523.308495                   NaN
# 212400                 1663.550266                   NaN
# 212401                         NaN                   NaN
# 212404                         NaN                   NaN
#
#         nearest_railroad_dist_ft      nearest_water_name  \
# 7                            NaN                     NaN
# 8                            NaN                     NaN
# 12                           NaN             Calumet Riv
# 13                           NaN                     NaN
# 14                           NaN                     NaN
# ...                          ...                     ...
# 212391                       NaN  Chicago River North Br
# 212394                       NaN                     NaN
# 212400                       NaN                     NaN
# 212401                       NaN                     NaN
# 212404                       NaN                     NaN
#
#         nearest_water_dist_ft  nearest_neighbor_1_dist_ft  \
# 7                         NaN                   29.975556
# 8                         NaN                   33.950574
# 12                6391.361862                   32.903876
# 13                        NaN                   99.979888
# 14                        NaN                   34.995384
# ...                       ...                         ...
# 212391            1234.962907                   35.248738
# 212394            4453.705514                   18.327534
# 212400            3842.508220                   25.004712
# 212401                    NaN                  132.585415
# 212404            5058.506892                   24.003443
#
#         nearest_neighbor_2_dist_ft  nearest_neighbor_3_dist_ft
# 7                        34.997678                   59.952856
# 8                        40.386872                   61.836373
# 12                       32.903965                   57.680425
# 13                      146.228247                  152.142184
# 14                       40.227725                   71.496030
# ...                            ...                         ...
# 212391                   46.936961                   58.758696
# 212394                   24.763143                   36.645742
# 212400                   37.491853                   50.010324
# 212401                  155.464516                  160.264510
# 212404                   24.004172                   47.993710
#
# [69231 rows x 77 columns]

# %%
df_filtered = df_filtered.drop(columns=['nearest_park_dist_ft', 'nearest_railroad_dist_ft'])

# %%
df_check = df_filtered.groupby(["Sale Year"])
df_check.size().sort_values(ascending= False)
# Out:
# Sale Year
# 2018    35029
# 2019    34202
# dtype: int64

# %%
df_filtered.to_csv('df_filtered.csv', encoding='utf-8')
